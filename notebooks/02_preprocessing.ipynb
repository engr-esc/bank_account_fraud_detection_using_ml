# %% [markdown]
# # 02 - Preprocessing and Feature Engineering
#
# This sectional notebook contains the preprocessing, applied EDA, feature engineering, feature selection, and dimensionality reduction section. Run the full notebook for a fully executable workflow.
